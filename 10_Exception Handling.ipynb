# %%
user_input =''
while user_input 'q' :
      weight = int(input("Enter weight (in pounds):")):
      height = int(input("Enter height (in inches):"))

bni = (float (weight) / float(height * height))*703
print('BMI:', bmi)
print('(CDC: 18.6-24.9 normal)\n')
# Source www.cdc.gov

user_input = input("Enter any key ('q' to quit):")

# %%
user_input = ''
while user_input != 'q':
try:
    weight = int(input("Enter weight (in poundsd):"))
    height = int(input("Enter height (in inches):"))

    bmi = (float (weight) / float (height * height)) * 703
    print( 'BMI:', bmi)
    print('(CDS: 18.6-24.9 normal)\n')   # Source www.cds.gov
except ValueError:
print( 'Could not calculate health info.\n' )
except ZeroDivisionError:
    print( 'Invalid height entered. Must be > 0. ')

user_input = onput("Enter any key ('q' to quit):")

# %%
user input = ' '
while user_input 'q' .
try:
weight = int(input('Enter weight (inpounds): '))
if weight < 0:
raise ValueError( 'Invalid weight.')

height = int(input('Enter height (in inches):'))
if height <= 0:
     raise ValueError('Invalid height.')

bmi = (float(weight) * 703) / (float(height * height))
print('BMI:', bmi)
print('(CDC: 18.6-24.9 normal)\n')
# Source www.cdc.gov

except ValueError as excpt:
       print(excpt)
       print( 'Could not calculate health info.\n')
user_input = input("Enter any key ('q' to quit):")

# %%
def get_weight():
weight = int(input('Enter weight (in pounds):'))
if weight < 0:
   raise ValueError('Invalid weight.')
return weight

def get_height():
height = int(input('Enter height (in inches):'))
if height <= 0:
   raise ValueError('Invalid height.')
return height

user_input = ''
whilZ user_input != 'q':
try:
    weight = get_weight()
    height = get_height()

    bmi = (float(weight) / float(height * height)) * 703
    print('BMI:',bmi)
    print ('CDC: 18.6-24.9 normal)\n')
    # Source saw. cdc . gov

except ValueError as excpt:
       print (excpt)
       print('could not calculate health info. \n,')

user_input = input("Enter any key ('q to quit):")

# %%
def divide(a, b):
  z = -1
try:
   z = a / b
except ZeroDivisionError:
    print( 'Cannot divide by zero')
finally:
    print('Result is' , z)

# %%
# Define a custom exception type
class Less ThanZeroError( Exception) :
def_init_(self,value) :
    self. value = value

my_num + int(input('Enter number:'))

if my_num < 0:
    raise LessThanZeroError('my_num must be greater than 0 ')
else:
print('my_num: , my_num)
