# %%
1 = [-9, -47, -6, -21, 3, -25, -23]
counter =
i=0

for i in 1:
    if i < O:
counter = counter + I
print ("counter:" , counter)

# %%
curr_power = 2
user char = input( ' Enter either "y" or "n"

while user_char =='y':
print (curr_power)
curr_power = curr_power * 2
user_char = input( 'Enter either"y" or "n" :')

print( 'Done' )

# %%
nose = ' 0 ' # Looks a little a nose
user_value = '_'

while user value != 'q'
    print (f' {user_value} {user _ value}' ) # Print eyes
    print (f' {nose}') # Print nose
    print (user_value*5)# print mouth
    print( '\n')

# Get new character for eyes and mouth
user_input input("Enter a character ( 'q' for quit) : \n")
user_value = user_input[0]

print( Goodbye. Nn ' )

# %%
# Read num from user ...
num = int(input( 'Enter number:'))

# print each digit
while num > 0:
    print(num X 10)
    num = num // 10

# %%
n = int(input( 'Enter the value of n: ' ) )
result =1
i = 1
while i <= n:
  result = result * i
  i += 1
print("factorial of", n, "is", result)

# %%
total = 0
counter =0
user_inp = int(input())

while user_inp > O:   # Get values until O (or Less)
      total = total + user_inp
      counter = counter + 1
      user_inp(input())

print(f'Average: {total / counter:.of}\n')

# %%
# Iterating N times using a Loop variable

N = int(input( 'Enter the value: '))
i = 1
while i <= N:
    # Loop body statements go here
    print(i)
    i = i + 1

# %%
i = 5
while i >= 1:
     # Loop body statements go here
    print(i)
    i= i - 1

# %%
i = 0

N = int(input( 'Enter the value of N:'))
while i <= N:
    # Loop body statements go here
    print(i)
    i + i +2

# %%
channels = {
'MTV': 35,
'CNN': 28,
'FOX': 11,
'NBC': 4,
'CBS': 12,
}

for c in channels :
    print(f' {c} is on channel {channels[c]}')

# %%
my _ str = ''
for character in "Take me to the moon. " :
     my_str += character + '_'
print(my_str)

# %%
daily _ revenues = [
2356.   # Monday
1800.   # Tuesday
1792.   # Wednesday
2058 .  # Thursday
1988 .  # Friday
2002 .  # Saturday
1890.   # Sunday
]

total = 0
for day in daily_revenues:
    total += day

    average= total / len(daily_revenues)

print(f'Week1y revenue: ${total: .2f}')
print(f'Dai1y average revenue: ${average:.2f}')

# %%
# Generate numbers between 0 to 6
for i in range(6):
    print (i)

# %%
for num in range(l, l0, 2):
print (num)

# %%
Program to print all 2-letter domain names.

Note that ord() and chr() convert between text and the ASCII or Unicode encoding:
     ord( 'a') yields the encoded value of 'a, the number 97.
     ord('a')+1 adds 1 to the encoded value of 'a', giving 98.


    chr(ord('a' )+1) converts 98 back into a letter, producing 'b '
  """
print( 'Two-letter domain names: ' )
letterl = 'a'
letter2 = '?'
while letter1 <= 'z':   # outer loop
     letter2  'a'
     while letter2 <= 'z' :  # Inner loop

      print(f'{letter1} {letter2}.com')
      letter2 chr(ord(1etter2) + 1)
letterl = chr(ord(letterl) + 1)

# %%
user_input = input( 'Enter phone number: )

index = 0
for character in user _ input:
    print(f' Element {index} is: {character} )
    index += 1

# %%
user_input = input( 'Enter phone number:')
phone_number =''

for character in user _ input:
if ( 'O ' <= character <= '9' ) or (character == '_' ):
     phone_number += character
elif ( 'a ' <= character <= 'c') or ('A '<= character <= 'c'):
     phone_number • 2 •
#FIXME: Add remaining eLif branches
else:
phone_number += '?'

print(f'Numbers only: {phone_number} ' )

# %%
for c in 'python' :
    print(c)
print( 'done ' )

# %%
for c in 'python':
    if c ==
        break
    print (c)
print( 'done')

# %%
for c in 'python' :
  if c == 't' :
     continue
  print(c)
print( 'done')

# %%
names = ['Jayesh' , 'Chetan' , 'Manish' , 'Varsha' , 'Jai']
num = int(input( 'Enter number of names to print: '))
for i in range(len(names)):
if i==num:
  break
print(names[i],ends='')
else :
print("All names printed.")

# %%
origins = [4, 8, 10]

for index in range(len(origins)):
value = origins [index] Retrieve value of element
print(f' Element {index}: {value}' )
